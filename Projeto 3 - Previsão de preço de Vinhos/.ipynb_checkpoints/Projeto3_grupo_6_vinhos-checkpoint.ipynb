# %% [markdown]
# ___
# ## Ciência dos Dados - PROJETO 3 - INSPER

# %% [markdown]
# ___
# #### Theo
#
# #### Abel
#
# #### Gustavo Pierre
#
# #### Victor Jurdi
#
# ___

# %% [markdown]
# # Wines Review

# %% [markdown]
# ___
#
# ## A. INTRODUÇÃO

# %% [markdown]
# Para o Projeto 3 de Ciências dos Dados, o grupo escolheu trabalhar com vinhos. O nosso DataSet contém 10 variavéis(Pais de origem,descrição do vinho,designação, pontos na avaliação, preço, provincia, região, variedade e a adega produtora. Com isso nosso grupo procura prever o preço do vinho através das variavéis mais qualificadas, que serão, o país, os pontos (nota do vinho) e o tipo da uva.

# %% [markdown]
# ___
# ## B. MINERANDO DADOS e CARACTERÍSTICAS DO DATASET

# %% [markdown]
# [Detalhe aqui as características da base de dados além da análise descritiva.]

# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
#from operator import itemgetter

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Lenovo\OneDrive\Desktop\Insper\3° Semestre\CData - DP\projeto_Cdata\Projeto 3 - Previsão de preço de Vinhos

# %% [markdown]
# ### BASE DE DADOS

# %%
x=pd.read_csv('winemag-data_first150k.csv')
x.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
del x["Unnamed: 0"]

# %%
x.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
x.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
#x.variety.value_counts()

# %%
x["Frequencia"] = 0
x.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery  Frequencia
# 0                    Heitz           0
# 1  Bodega Carmen Rodríguez           0
# 2                 Macauley           0
# 3                    Ponzi           0
# 4     Domaine de la Bégude           0

# %%
dic = {}
for e in x.variety:
    if e not in dic:
        dic[e] = 1
    
        
    elif e in dic:
        dic[e] +=1

# %%
lista = []
for e in dic:
    if dic[e] > 0:
        lista.append(dic[e]/len(dic))

# %%
dic2 = {}
i=0
for e in x.variety:
    if e not in dic2:
        dic2[e] = 1

# %%
i=0
for e in dic2:
    dic2[e] = lista[i]
    i+=1

# %%
lista2=[]
for uva in x.variety:
    lista2.append(dic2[uva])

# %%
x.Frequencia = lista2

# %%
x.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery  Frequencia
# 0                    Heitz   20.253165
# 1  Bodega Carmen Rodríguez    0.349684
# 2                 Macauley   10.000000
# 3                    Ponzi   22.612342
# 4     Domaine de la Bégude    0.039557

# %%
print(x.duplicated("Frequencia"))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10        False
# 11         True
# 12         True
# 13        False
# 14         True
# 15        False
# 16         True
# 17        False
# 18        False
# 19         True
# 20        False
# 21        False
# 22         True
# 23         True
# 24         True
# 25         True
# 26         True
# 27         True
# 28         True
# 29        False
#           ...
# 150900     True
# 150901     True
# 150902     True
# 150903     True
# 150904     True
# 150905     True
# 150906     True
# 150907     True
# 150908     True
# 150909     True
# 150910     True
# 150911     True
# 150912     True
# 150913     True
# 150914     True
# 150915     True
# 150916     True
# 150917     True
# 150918     True
# 150919     True
# 150920     True
# 150921     True
# 150922     True
# 150923     True
# 150924     True
# 150925     True
# 150926     True
# 150927     True
# 150928     True
# 150929     True
# Length: 150930, dtype: bool

# %%
novo_x = x.drop_duplicates(['Frequencia'])
novo_x
# Out:
#             country                                        description  \
# 0                US  This tremendous 100% varietal wine hails from ...
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 
# 14622     Australia  Although they've mis-appropriated the term ‘me...
# 14678         Italy  Peach, apricot, cherry blossom and a touch of ...
#
#                                      designation  points  price  \
# 0                              Martha's Vineyard      96  235.0
# 1           Carodorum Selección Especial Reserva      96  110.0
# 2                  Special Selected Late Harvest      96   90.0
# 3                                        Reserve      96   65.0
# 4                                     La Brûlade      95   66.0
# 10                            Ronco della Chiesa      95   80.0
# 13                       Château Montus Prestige      95   90.0
# 15                                        Sigrid      95   90.0
# 17                        6 Años Reserva Premium      95   80.0
# 18                                 Le Pigeonnier      95  290.0
# 20                                    Grignolino      95   24.0
# 21                       Prado Enea Gran Reserva      95   79.0
# 29                               The Funk Estate      94   60.0
# 30                                       Bergulé      90   15.0
# 32                                 Vigna Piaggia      90    NaN
# 33                    Nonpareil Trésor Rosé Brut      90   22.0
# 36                                           NaN      90   60.0
# 39                                       Riserva      90   29.0
# 40                                        Amandi      90   17.0
# 42                               Private Reserve      90   55.0
# 57                                       Reserve      90   25.0
# 58                                   Final Final      90   30.0
# 64                                           NaN      91   23.0
# 72                                Bussia Riserva      91    NaN
# 73                                           NaN      91   19.0
# 89                                    Magnificat      91   50.0
# 91                Marquês de Marialva Rosé Bruto      86   12.0
# 92                                        Nature      86   22.0
# 95                  Château Beauvillain-Monpezat      86   14.0
# 98                                     Pigmentum      86   15.0
# ...                                          ...     ...    ...
# 2075                                         Dry      90   15.0
# 2390                           S. Agata dei Goti      90   20.0
# 2411                                     Veritas      89   20.0
# 2453                                    El Perer      96  770.0
# 2468                       Silvaspoons Vineyards      86   16.0
# 3317                             Keramos Riserva      89   49.0
# 3435                                    Beck Ink      91    NaN
# 3467                                         NaN      89   21.0
# 3567                                         NaN      89   15.0
# 3589                    Heringer Estate Vineyard      89   35.0
# 3846                                      Radice      90   21.0
# 3935                               The Signature      94   55.0
# 4021                           Fox Hill Vineyard      85   25.0
# 4596                                         NaN      91   16.0
# 4789                                     Riserva      86   29.0
# 5179                      Los Tesoros de Joaquin      88   30.0
# 5223                         Valentino Sweet Red      90   60.0
# 5654                                      Lighea      88   20.0
# 7636                                  Descendant      92  125.0
# 7686                     Single Organic Vineyard      89   15.0
# 10772                              Colleallodole      95   70.0
# 11572                           Aszú 6 Puttonyos      96  125.0
# 12541                                        NaN      92   27.0
# 12984                               Primo Rosato      86   18.0
# 13191                                   Ice Wine      91   43.0
# 13261                                        NaN      89   40.0
# 13631                                    Riserva      90    NaN
# 13831                                        NaN      87    NaN
# 14622  Flying Piano Hand Select Recital Meritáge      86   11.0
# 14678       Millesimato Cuvée Tenuta Val de Brun      87   19.0
#
#                   province                                       region_1  \
# 0               California                                    Napa Valley
# 1           Northern Spain                                           Toro
# 2               California                                 Knights Valley
# 3                   Oregon                              Willamette Valley
# 4                 Provence                                         Bandol
# 10      Northeastern Italy                                         Collio
# 13        Southwest France                                        Madiran
# 15                  Oregon                              Willamette Valley
# 17          Northern Spain                               Ribera del Duero
# 18        Southwest France                                         Cahors
# 20              California                                    Napa Valley
# 21          Northern Spain                                          Rioja
# 29              Washington                        Walla Walla Valley (WA)
# 30                Bulgaria                                            NaN
# 32                 Tuscany                         Brunello di Montalcino
# 33            France Other                                   Vin Mousseux
# 36            Rhône Valley                            Châteauneuf-du-Pape
# 39                 Tuscany                               Chianti Classico
# 40                 Galicia                                  Ribeira Sacra
# 42                   Idaho                                            NaN
# 57                New York                                   Finger Lakes
# 58              Washington                           Columbia Valley (WA)
# 64              Alentejano                                            NaN
# 72                Piedmont                                         Barolo
# 73                  Oregon                              Willamette Valley
# 89              California                                    Napa Valley
# 91         Beira Atlantico                                            NaN
# 92                  Veneto                                       Prosecco
# 95        Southwest France                                         Cahors
# 98        Southwest France                                          Buzet
# ...                    ...                                            ...
# 2075                Ankara                                            NaN
# 2390        Southern Italy                          Falanghina del Sannio
# 2411                Tikves                                            NaN
# 2453             Catalonia                                        Priorat
# 2468            California                                           Lodi
# 3317     Sicily & Sardinia                           Cannonau di Sardegna
# 3435   Weinland Österreich                                            NaN
# 3467            California  Antelope Valley of the California High Desert
# 3567              Piedmont                                Dolcetto d'Alba
# 3589            California                                     Clarksburg
# 3846         Central Italy                           Lambrusco di Sorbara
# 3935       South Australia                                        Barossa
# 4021            California                               Mendocino County
# 4596    Northeastern Italy                                         Collio
# 4789        North Carolina                                     Swan Creek
# 5179            California                               Livermore Valley
# 5223       Vipavska Dolina                                            NaN
# 5654     Sicily & Sardinia                                        Sicilia
# 7636       South Australia                                 Barossa Valley
# 7686      Mendoza Province                                        Mendoza
# 10772        Central Italy                       Sagrantino di Montefalco
# 11572               Tokaji                                            NaN
# 12541       Hemel en Aarde                                            NaN
# 12984    Sicily & Sardinia                              Isola dei Nuraghi
# 13191             New York                                   Finger Lakes
# 13261               Veneto            Amarone della Valpolicella Classico
# 13631   Northeastern Italy                                     Alto Adige
# 13831              Tuscany                            Rosso di Montalcino
# 14622      Australia Other                        South Eastern Australia
# 14678               Veneto         Prosecco di Conegliano e Valdobbiadene
#
#                       region_2                        variety  \
# 0                         Napa             Cabernet Sauvignon
# 1                          NaN                  Tinta de Toro
# 2                       Sonoma                Sauvignon Blanc
# 3            Willamette Valley                     Pinot Noir
# 4                          NaN             Provence red blend
# 10                         NaN                       Friulano
# 13                         NaN                         Tannat
# 15           Willamette Valley                     Chardonnay
# 17                         NaN                    Tempranillo
# 18                         NaN                         Malbec
# 20                        Napa                           Rosé
# 21                         NaN              Tempranillo Blend
# 29             Columbia Valley                          Syrah
# 30                         NaN                         Mavrud
# 32                         NaN                     Sangiovese
# 33                         NaN                Sparkling Blend
# 36                         NaN        Rhône-style White Blend
# 39                         NaN                      Red Blend
# 40                         NaN                         Mencía
# 42                         NaN                   Petite Sirah
# 57                Finger Lakes                       Riesling
# 58             Columbia Valley       Cabernet Sauvignon-Syrah
# 64                         NaN                 Portuguese Red
# 72                         NaN                       Nebbiolo
# 73           Willamette Valley                     Pinot Gris
# 89                        Napa                       Meritage
# 91                         NaN                           Baga
# 92                         NaN                          Glera
# 95                         NaN                  Malbec-Merlot
# 98                         NaN                  Merlot-Malbec
# ...                        ...                            ...
# 2075                       NaN                 Kalecik Karasi
# 2390                       NaN                     Falanghina
# 2411                       NaN                         Vranec
# 13261                                 La Dama    2.661392
# 13631  Cantina Produttori San Michele Appiano    0.060127
# 13831                                 Renieri    2.129747
# 14622                         Ozwell Vintners    0.153481
# 14678                                 Astoria    0.939873
#
# [157 rows x 11 columns]

# %%
x.loc[(x.price<50),'Preço'] = 'Até 50'
x.loc[(x.price>50)&(x.price<=200),'Preço'] = 'Até 200'
#x.loc[(x.price>100)&(x.price<=200),'Preço'] = 'Até 200'
x.loc[(x.price>200)&(x.price<=400),'Preço'] = 'Até 400'
#x.loc[(x.price>300)&(x.price<=400),'Preço'] = 'Até 400'
x.loc[(x.price>400)&(x.price<=600),'Preço'] = 'Até 600'
#x.loc[(x.price>500)&(x.price<=600),'Preço'] = 'Até 600'
x.loc[(x.price>600)&(x.price<=800),'Preço'] = 'Até 800'
#x.loc[(x.price>700)&(x.price<=800),'Preço'] = 'Até 800'
x.loc[(x.price>800)&(x.price<=1000),'Preço'] = 'Até 1000'
#x.loc[(x.price>900)&(x.price<=1000),'Preço'] = 'Até 1000'
x.loc[(x.price>1000)&(x.price<=1500),'Preço'] = 'Até 1500'
#x.loc[(x.price>1500)&(x.price<=2000),'Preço'] = 'Até 2000'
x.loc[(x.price>2000),'Preço'] = 'Mais que 2000'

# %%
x.loc[(x.points<=80),'Pontos'] = '80 pontos'
x.loc[(x.points>80)&(x.points<=85),'Pontos'] = '81 - 85 pontos'
x.loc[(x.points>85)&(x.points<=90),'Pontos'] = '86 - 90 pontos'
x.loc[(x.points>90)&(x.points<=95),'Pontos'] = '91 - 95 pontos'
x.loc[(x.points>95)&(x.points<=100),'Pontos'] = '95 - 100 pontos'

# %% [markdown]
# ### ANÁLISE DESCRITIVA

# %%
ct = pd.crosstab(x.Pontos, x.Preço)
ct.plot(kind='bar');
ax = plt.subplot(111);
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
x.points.corr(x.price)
# Out:
# 0.4598634287426046

# %%
x.Frequencia.corr(x.price)
# Out:
# 0.11948549716429052

# %%
x.Frequencia.corr(x.points)
# Out:
# 0.07755501939155625

# %%
plt.hist(x["country"]);
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6564: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\Users\Lenovo\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6565: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))

# %%
plt.hist(x["Preço"]);

# %%
plt.hist(x.Pontos, size = 10);

# %% [markdown]
# ___
# ## C. MODELOS DE PREDIÇÃO

# %% [markdown]
# o MODELO DE PREDIÇÃO PELA MÉDIA (Sem uso de variável explicativa).

# %% [markdown]
# o MODELO DOS K VIZINHOS MAIS PRÓXIMOS (K-Nearest Neighbors Regression)

# %% [markdown]
# o MODELO DE REGRESSÃO LINEAR (Multiple Linear Regression)

# %% [markdown]
# o MODELO DE ÁRVORES DE REGRESSÃO (Decision Tree Regression)

# %% [markdown]
# ___
# ## D. PROCESSO E ESTATÍSTICAS DE VALIDAÇÃO

# %% [markdown]
# [Esse item depende dos resultados das modelagens anteriores! Organize-os aqui de forma clara!]

# %% [markdown]
# ___
# ## E. CONCLUSÃO

# %% [markdown]
# ___
# ## F. REFERÊNCIAS BIBLIOGRÁFICAS
